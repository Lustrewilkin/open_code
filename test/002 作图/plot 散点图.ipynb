# %%
import numpy as np
# import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt

# %%
rd = np.random.random([200,1])
data = np.random.randint(83, 90, size=[200,1])
data = data+rd

# %%
rangex = np.arange(1,101)
rangex = np.reshape(rangex, [100,1])
rangex = np.concatenate((rangex,rangex))

# %%
class1 = np.zeros([100,1])
class2 = class1 + 1

classes = np.concatenate((class1,class2))

# %%
ndata = np.concatenate((rangex,data,classes),axis = 1)
ndata.shape
# Out:
# (200, 3)

# %%
pdata = pd.DataFrame(ndata, columns=['range', 'accurace', 'class'])
pdata.head()
# Out:
#    range   accurace  class
# 0    1.0  89.460007    0.0
# 1    2.0  89.468068    0.0
# 2    3.0  89.429970    0.0
# 3    4.0  84.411592    0.0
# 4    5.0  83.055839    0.0

# %%
plt.figure()
sns.set(style="whitegrid",font_scale=1.2)#设置主题，文本大小
g=sns.regplot(x='range', y='accurace', data=pdata,
             color='#000000',#设置marker及线的颜色
             marker='*',#设置marker形状
             )

# %%
plt.figure(dpi=200)
sns.set(style="whitegrid",font_scale=1.2)
g=sns.lmplot(x='range', y='accurace', data=pdata,
             hue='class',
             markers=['+','^']   #设置散点marker
             )
plt.axis([0, 101, 80, 95])
g.fig.set_size_inches(10,8)

# %%
sns.set(style="whitegrid",font_scale=1.5)#设置主题，文本大小
g = sns.jointplot(x='range', y='accurace', data=pdata,#输入两个绘图变量
                 color='#098154',#修改颜色
                 marginal_kws=dict(bins=15, #hist箱子个数
                                    kde=True,#开启核密度图
                                    color='#c72e29',#直方图hist填充色                                    
                                   )
                    # ,kind = 'hex'
                 )
g.fig.set_size_inches(10,8)#设置图尺寸
g.plot_joint(sns.kdeplot, zorder=0, n_levels=6,color='red')
# g.ax_marg_y.boxplot(pdata['accurace'],boxprops={'color':'r',})
# plt.show()

# %% [markdown]
# # signal

# %%
rd = np.random.random([200,1])
data = np.random.randint(83, 90, size=[200,1])
data = data+rd

# %%
fig, ax = plt.subplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4cc90ac77153> in <module>
# ----> 1 fig, ax = plt.subplot()
#
# TypeError: cannot unpack non-iterable AxesSubplot object
