# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import seaborn as sns

# %%
poname = ['P3','C3','F3','Fz','F4','C4','P4','Cz','Fp1','Fp2','T3','T5','O1','O2','F7','F8','T6','T4']

pov = {0	:	np.	array	(	[	-0.545	,	-0.67302	]	)	,
1	:	np.	array	(	[	-0.71935	,	0	]	)	,
2	:	np.	array	(	[	-0.545	,	0.67302	]	)	,
3	:	np.	array	(	[	0	,	0.71935	]	)	,
4	:	np.	array	(	[	0.545	,	0.67302	]	)	,
5	:	np.	array	(	[	0.71935	,	0	]	)	,
6	:	np.	array	(	[	0.545	,	-0.67302	]	)	,
7	:	np.	array	(	[	0	,	0	]	)	,
8	:	np.	array	(	[	-0.30883	,	0.95048	]	)	,
9	:	np.	array	(	[	0.30883	,	0.95048	]	)	,
10	:	np.	array	(	[	-0.99457	,	0	]	)	,
11	:	np.	array	(	[	-0.80498	,	-0.58672	]	)	,
12	:	np.	array	(	[	-0.30883	,	-0.95048	]	)	,
13	:	np.	array	(	[	0.30883	,	-0.95048	]	)	,
14	:	np.	array	(	[	-0.80852	,	0.58743	]	)	,
15	:	np.	array	(	[	0.80852	,	0.58743	]	)	,
16	:	np.	array	(	[	0.80498	,	-0.58672	]	)	,
17	:	np.	array	(	[	0.99457	,	0	]	)	,
}

# %%
import pandas as pd 
position = pd.DataFrame(pov).T
position.head
# position.columns[1]
# Out:
# <bound method NDFrame.head of           0        1
# 0  -0.54500 -0.67302
# 1  -0.71935  0.00000
# 2  -0.54500  0.67302
# 3   0.00000  0.71935
# 4   0.54500  0.67302
# 5   0.71935  0.00000
# 6   0.54500 -0.67302
# 7   0.00000  0.00000
# 8  -0.30883  0.95048
# 9   0.30883  0.95048
# 10 -0.99457  0.00000
# 11 -0.80498 -0.58672
# 12 -0.30883 -0.95048
# 13  0.30883 -0.95048
# 14 -0.80852  0.58743
# 15  0.80852  0.58743
# 16  0.80498 -0.58672
# 17  0.99457  0.00000>

# %%
fig, ax = plt.subplots(dpi = 300)
sns.scatterplot(x = position.columns[0], y= position.columns[1],  data=position, sizes=(100,1000))
plt.xticks([])
plt.yticks([])
plt.xlim(-1.50, 1.50)  # 设置首界面X轴坐标范围
plt.ylim(-1.50, 1.50)  # 设置首界面Y轴坐标范围

plt.show()

# %%
position[0]

# %%
fig, ax = plt.subplots(dpi = 300)
plt.scatter(x=position[0], y=position[1], s = 200)
plt.xticks([])
plt.yticks([])
plt.xlim(-1.50, 1.50)  # 设置首界面X轴坐标范围
plt.ylim(-1.50, 1.50)  # 设置首界面Y轴坐标范围

for i in range(len(position.values)):
    # plt.annotate(poname[i],xy = (position[0][i],position[1][i]),xytext = (position[0][i]-0.05,position[1][i]-0.05), 
    #             fontsize=8)
     plt.text(position[0][i],position[1][i]-0.04,poname[i],ha="center",fontsize=8)# ,va= "bottom")
plt.savefig('D:\\Desktop\\素材\\GNN1\\brainmap.png')
plt.show()
