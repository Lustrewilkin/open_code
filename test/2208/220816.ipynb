# %%
from torch.utils.tensorboard import SummaryWriter
import os
import surpport.mySQL as mySQL
import surpport.myfunction as MF
from surpport.Args import Args
from surpport.dataprocess import dataload
import torch.nn.functional as F
import torch
import numpy as np
# Out:
# Using backend: pytorch

# %% [markdown]
# ## dataload 重构

# %% [markdown]
# ### dataload

# %%
from torch.utils.data import Dataset
from dgl.data.utils import load_graphs
from os.path import join
from dgl.dataloading import GraphDataLoader

class cross_Dataset(Dataset):
    def __init__(self, arg) -> None:
        super(Dataset, self).__init__()
        self.arg = arg # type: Args
        self.load(arg)
    
    def load(self, arg):
        f = arg.select_f # type: str
        ori = r'E:\DATABASE\FirstGNN\CrossData'
        path = join(ori, f+'_dgl_graph')
        gdata = torch.load(path)
        self.graphs, self.labels = gdata['graphs'], gdata['labels']

    def __getitem__(self, index):
        return self.graphs[index], self.labels[index]

    def __len__(self):
        return len(self.graphs)

def c_dataload(arg, model, opt, alpha):
    """cross exp dataload

    Args:
        arg (Args): Args need
        model (nn.Moudle): ours model
        opt (torch.opt): torch.opt
        alpha (int): 1~11, contain by num of patients

    Returns:
        tuple: arg, tr_dataloader, ts_dataloader
    """
    dataset = cross_Dataset(arg)
    if not arg.new_train:
        MF.continue_tr(arg.dir, model, opt, arg)
    else:
        end_num = alpha * 1875 # 单人一个
        lenth = len(dataset)
        arg.tr_id = list(range(end_num))
        arg.ts_id = list(range(end_num, lenth-1))
    
    train_dataset = torch.utils.data.Subset(
        dataset=dataset, indices=arg.tr_id)
    test_dataset = torch.utils.data.Subset(
        dataset=dataset, indices=arg.ts_id)
    tr_dataloader = dataloader(
        train_dataset, arg.batch_size, collate=MF.collate, shuffle=True)
    ts_dataloader = dataloader(
        test_dataset, arg.batch_size, collate=MF.collate, shuffle=True)
    return arg, tr_dataloader, ts_dataloader

def dataloader(dataset, batch_size, collate, shuffle):
    gdataloader = GraphDataLoader(
        dataset,
        collate_fn=collate,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=False
        # sampler = sampler
    )
    return gdataloader

# %%
arg = Args()
arg.d_prepare('Cross', 2)
dataset = cross_Dataset(arg)

# %%
dataset[1]
# Out:
# (Graph(num_nodes=18, num_edges=98,
#        ndata_schemes={'h': Scheme(shape=(128,), dtype=torch.float32)}
#        edata_schemes={'f': Scheme(shape=(1,), dtype=torch.float32)}),
#  'labels')

# %% [markdown]
# ### 构造测试

# %%
def load(f: int, name: str, graphs: list, labels: list):
    f = f'f{f}'
    ori = r'E:\DATABASE\FirstGNN\graphbin'
    path = join(ori, name, f+'_dgl_graph.bin')
    g, l = load_graphs(path)
    graphs.extend(g)
    labels.extend(l['labels'])

# %%
arg = Args()
save_path = r'E:\DATABASE\FirstGNN\CrossData'
fs = [2, 6, 7, 15]
names = arg.patient
for f in fs:
    graphs = []
    labels = []
    for name in names:
        load(f, name, graphs, labels)
    gdata = {'graphs': graphs, 'labels': labels}
    file_path = join(save_path, f'f{f}_dgl_graph')
    torch.save(gdata, file_path)

# %%
gdata = {'graphs': graphs, 'labels': labels}
save_path = r'E:\DATABASE\FirstGNN\CrossData'
file_path = join(save_path, f'f{f}_dgl_graph') 
torch.save(gdata, file_path)

# %%
gdata = torch.load(r'E:\DATABASE\FirstGNN\CrossData\f2_dgl_graph')

# %%
l = gdata['labels']

# %%
l[15]
# Out:
# tensor([0])

# %%
del gdata
del graphs
del labels

# %% [markdown]
# ### 运行测试

# %%
import sys
# sys.path.append(r'E:\CODEBASE\myDGL\FirstDGL\Experiment\Baseline\GraphModel\GNN')
sys.path.append(r'E:\CODEBASE\myDGL\FirstDGL\Experiment\Baseline')
from NoneGraph.EEGNet import EEGNet2

# %%
from surpport.nnstructure import Classifier7

def m_pre():
    arg = Args()
    # model = GNN.DGCN()
    # model = Classifier7(arg)
    model = EEGNet2()
    model = model.cuda()
    return arg, model

def recorder_build(arg):
    base_rcd = mySQL.gen_base_rcd(arg)
    recorder = {'base': base_rcd}
    return recorder

# %%
names = ['kly']
fs = [2, ]
for f in fs:
    arg, model = m_pre()
    arg.d_prepare('Cross', f)
    # ! 每次运行都改
    arg.m_info(m_name='eegnet2', m_task='220822_cross_test', num=2)
    base_rcd = mySQL.gen_base_rcd(arg)
    recorder = {'base': base_rcd}
    writer = SummaryWriter(arg.tar_path+'\\Journal')

    # ! 根据模型修改
    opt_arg = {'params': model.parameters(),}
    # opt_arg = {'params': model.parameters(),'lr': 6e-5, 'eps': 1e-8, 'weight_decay': 0.1}
    opt = torch.optim.Adam(**opt_arg)

    arg, tr_dataloader, ts_dataloader = c_dataload(arg, model, opt, 9)

# %%
td = iter(tr_dataloader)
g, l = next(td)

# %%
st = 41
step = 40
arg.display_freq = 50
for epoch in range(st, step+st):
    print(epoch)
    recorder[str(epoch)+'-th'] = dict()
    rd = recorder[str(epoch)+'-th']
    # 由于图经过拼合，所以需要多一个dataloader的过程
    # 前两个是list
    tr_args = [epoch, model, opt, tr_dataloader, arg, writer]
    tr_loss, tr_acc = MF.train(*tr_args)
    mySQL.rcd_log(tr_loss, tr_acc, writer, rd, epoch, 'train')

    tr_args[3] = ts_dataloader
    el_loss, el_acc, logits, labels = MF.evaluate(*tr_args)

    mySQL.rcd_log(el_loss, el_acc, writer, rd, epoch, 'test')
    mySQL.rcd_result(logits, labels, rd)

    val_acc = np.mean(el_acc, axis=0)
    MF.save_best(val_acc, model, arg)

    mySQL.save_final(epoch, model, val_acc, arg, opt)

mySQL.save_recorder(recorder, arg, 'flow')
print('best acc: %.4f' % (arg.best_acc))
writer.close()
# Out:
# 41
# Epoch 41, Iter 050,train loss = 1.2588, train acc = 0.5000
# Epoch 41, Iter 100,train loss = 1.1670, train acc = 0.7500
# Epoch 41, Iter 150,train loss = 1.1612, train acc = 0.6562
# Epoch 41, Iter 200,train loss = 1.1390, train acc = 0.6875
# Epoch 41, Iter 250,train loss = 1.2098, train acc = 0.5312
# Epoch 41, Iter 300,train loss = 1.2138, train acc = 0.5625
# Epoch 41, Iter 350,train loss = 1.2738, train acc = 0.5625
# Epoch 41, Iter 400,train loss = 1.1632, train acc = 0.6250
# Epoch 41, Iter 450,train loss = 1.2928, train acc = 0.6562
# Epoch 41, Iter 500,train loss = 1.2136, train acc = 0.6562
# Epoch 41, val loss = 1.5084, val acc = 0.3836
# 未达到期望，未保存模型
# 42
# Epoch 42, Iter 050,train loss = 1.1159, train acc = 0.7188
# Epoch 42, Iter 100,train loss = 1.2480, train acc = 0.5938
# Epoch 42, Iter 150,train loss = 1.1888, train acc = 0.5625
# Epoch 42, Iter 200,train loss = 1.1941, train acc = 0.5938
# Epoch 42, Iter 250,train loss = 1.2300, train acc = 0.5000
# Epoch 42, Iter 300,train loss = 1.2181, train acc = 0.5625
# Epoch 42, Iter 350,train loss = 1.2730, train acc = 0.5625
# Epoch 42, Iter 400,train loss = 1.1581, train acc = 0.7500
# Epoch 42, Iter 450,train loss = 1.2327, train acc = 0.5938
# Epoch 42, Iter 500,train loss = 1.1340, train acc = 0.6250
# Epoch 42, val loss = 1.5155, val acc = 0.3895
# 未达到期望，未保存模型
# 43
# Epoch 43, Iter 050,train loss = 1.2117, train acc = 0.6250
# Epoch 43, Iter 100,train loss = 1.2224, train acc = 0.6250
# Epoch 43, Iter 150,train loss = 1.2601, train acc = 0.5625
# Epoch 43, Iter 200,train loss = 1.2199, train acc = 0.5312
# Epoch 43, Iter 250,train loss = 1.2118, train acc = 0.6250
# Epoch 43, Iter 300,train loss = 1.1417, train acc = 0.7188
# Epoch 43, Iter 350,train loss = 1.0903, train acc = 0.8750
# Epoch 43, Iter 400,train loss = 1.2038, train acc = 0.6875
# Epoch 43, Iter 450,train loss = 1.2252, train acc = 0.5938
# Epoch 43, Iter 500,train loss = 1.1479, train acc = 0.7188
# Epoch 43, val loss = 1.5066, val acc = 0.3937
# 未达到期望，未保存模型
# 44
# Epoch 44, Iter 050,train loss = 1.2568, train acc = 0.5312
# Epoch 44, Iter 100,train loss = 1.2041, train acc = 0.6250
# Epoch 44, Iter 150,train loss = 1.2979, train acc = 0.5312
# Epoch 44, Iter 200,train loss = 1.2348, train acc = 0.5938
# Epoch 44, Iter 250,train loss = 1.2549, train acc = 0.5625
# Epoch 44, Iter 300,train loss = 1.1726, train acc = 0.5625
# Epoch 44, Iter 350,train loss = 1.2916, train acc = 0.6250
# Epoch 44, Iter 400,train loss = 1.1278, train acc = 0.6875
# Epoch 44, Iter 450,train loss = 1.3398, train acc = 0.5625
# Epoch 44, Iter 500,train loss = 1.2262, train acc = 0.6562
# Epoch 44, val loss = 1.4872, val acc = 0.4099
# 未达到期望，未保存模型
# 45
# Epoch 45, Iter 050,train loss = 1.2266, train acc = 0.6875
# Epoch 45, Iter 100,train loss = 1.2504, train acc = 0.5938
# Epoch 45, Iter 150,train loss = 1.1857, train acc = 0.6250
# Epoch 45, Iter 200,train loss = 1.1899, train acc = 0.6875
# Epoch 45, Iter 250,train loss = 1.2652, train acc = 0.5938
# Epoch 45, Iter 300,train loss = 1.3452, train acc = 0.4375
# Epoch 45, Iter 350,train loss = 1.2190, train acc = 0.6250
# Epoch 45, Iter 400,train loss = 1.3929, train acc = 0.5000
# Epoch 45, Iter 450,train loss = 1.1731, train acc = 0.7500
# Epoch 45, Iter 500,train loss = 1.2560, train acc = 0.5938
# Epoch 45, val loss = 1.5181, val acc = 0.4088
# 未达到期望，未保存模型
# 46
# Epoch 46, Iter 050,train loss = 1.2266, train acc = 0.7500
# Epoch 46, Iter 100,train loss = 1.1282, train acc = 0.7188
# Epoch 46, Iter 150,train loss = 1.1199, train acc = 0.7188
# Epoch 46, Iter 200,train loss = 1.2341, train acc = 0.6562
# Epoch 46, Iter 250,train loss = 1.1643, train acc = 0.6875
# Epoch 46, Iter 300,train loss = 1.1837, train acc = 0.8125
# Epoch 46, Iter 350,train loss = 1.2225, train acc = 0.5000
# Epoch 46, Iter 400,train loss = 1.2435, train acc = 0.5312
# Epoch 46, Iter 450,train loss = 1.2440, train acc = 0.5312
# Epoch 46, Iter 500,train loss = 1.2414, train acc = 0.5938
# Epoch 46, val loss = 1.5120, val acc = 0.3881
# 未达到期望，未保存模型
# 47
# Epoch 47, Iter 050,train loss = 1.1650, train acc = 0.5938
# Epoch 47, Iter 100,train loss = 1.3331, train acc = 0.4688
# Epoch 47, Iter 150,train loss = 1.1727, train acc = 0.5938
# Epoch 47, Iter 200,train loss = 1.2677, train acc = 0.6562
# Epoch 47, Iter 250,train loss = 1.2246, train acc = 0.6875
# Epoch 47, Iter 300,train loss = 1.1839, train acc = 0.7500
# Epoch 47, Iter 350,train loss = 1.2132, train acc = 0.6875
# Epoch 47, Iter 400,train loss = 1.2258, train acc = 0.7188
# Epoch 47, Iter 450,train loss = 1.2213, train acc = 0.7188
# Epoch 47, Iter 500,train loss = 1.1662, train acc = 0.6250
# Epoch 47, val loss = 1.5038, val acc = 0.4155
# 未达到期望，未保存模型
# 48
# Epoch 48, Iter 050,train loss = 1.2348, train acc = 0.5938
# Epoch 48, Iter 100,train loss = 1.2343, train acc = 0.5625
# Epoch 48, Iter 150,train loss = 1.1890, train acc = 0.7500
# Epoch 48, Iter 200,train loss = 1.2175, train acc = 0.6250
# Epoch 48, Iter 250,train loss = 1.2397, train acc = 0.6875
# Epoch 48, Iter 300,train loss = 1.1884, train acc = 0.7500
# Epoch 48, Iter 350,train loss = 1.2695, train acc = 0.5312
# Epoch 48, Iter 400,train loss = 1.1703, train acc = 0.7188
# Epoch 48, Iter 450,train loss = 1.2176, train acc = 0.6250
# Epoch 48, Iter 500,train loss = 1.2596, train acc = 0.6250
# Epoch 48, val loss = 1.5150, val acc = 0.4031
# 未达到期望，未保存模型
# 49
# Epoch 49, Iter 050,train loss = 1.2121, train acc = 0.5625
# Epoch 49, Iter 100,train loss = 1.2296, train acc = 0.5938
# Epoch 49, Iter 150,train loss = 1.3674, train acc = 0.5000
# Epoch 49, Iter 200,train loss = 1.2089, train acc = 0.5938
# Epoch 49, Iter 250,train loss = 1.2268, train acc = 0.5938
# Epoch 49, Iter 300,train loss = 1.1798, train acc = 0.6250
# Epoch 49, Iter 350,train loss = 1.2660, train acc = 0.5000
# Epoch 49, Iter 400,train loss = 1.2242, train acc = 0.5312
# Epoch 49, Iter 450,train loss = 1.2750, train acc = 0.6562
# Epoch 49, Iter 500,train loss = 1.1179, train acc = 0.7500
# Epoch 49, val loss = 1.5152, val acc = 0.3942
# 未达到期望，未保存模型
# 50
# Epoch 50, Iter 050,train loss = 1.1520, train acc = 0.7188
# Epoch 50, Iter 100,train loss = 1.3180, train acc = 0.5625
# Epoch 50, Iter 150,train loss = 1.2561, train acc = 0.5938
# Epoch 50, Iter 200,train loss = 1.1843, train acc = 0.5938
# Epoch 50, Iter 250,train loss = 1.1514, train acc = 0.6875
# Epoch 50, Iter 300,train loss = 1.2914, train acc = 0.5000
# Epoch 50, Iter 350,train loss = 1.2413, train acc = 0.5312
# Epoch 50, Iter 400,train loss = 1.3357, train acc = 0.4688
# Epoch 50, Iter 450,train loss = 1.3099, train acc = 0.5938
# Epoch 50, Iter 500,train loss = 1.2682, train acc = 0.6250
# Epoch 50, val loss = 1.5244, val acc = 0.4045
# 未达到期望，未保存模型
# 51
# Epoch 51, Iter 050,train loss = 1.2352, train acc = 0.6562
# Epoch 51, Iter 100,train loss = 1.1884, train acc = 0.6562
# Epoch 51, Iter 150,train loss = 1.2407, train acc = 0.6250
# Epoch 51, Iter 200,train loss = 1.2275, train acc = 0.5312
# Epoch 51, Iter 250,train loss = 1.1916, train acc = 0.6562
# Epoch 51, Iter 300,train loss = 1.1115, train acc = 0.7188
# Epoch 51, Iter 350,train loss = 1.2400, train acc = 0.5625
# Epoch 51, Iter 400,train loss = 1.2165, train acc = 0.6875
# Epoch 51, Iter 450,train loss = 1.1632, train acc = 0.5312
# Epoch 51, Iter 500,train loss = 1.1522, train acc = 0.7188
# Epoch 51, val loss = 1.5201, val acc = 0.3932
# 未达到期望，未保存模型
# 52
# Epoch 52, Iter 050,train loss = 1.0984, train acc = 0.8125
# Epoch 52, Iter 100,train loss = 1.2614, train acc = 0.5625
# Epoch 52, Iter 150,train loss = 1.2105, train acc = 0.6250
# Epoch 52, Iter 200,train loss = 1.2409, train acc = 0.5938
# Epoch 52, Iter 250,train loss = 1.2363, train acc = 0.5312
# Epoch 52, Iter 300,train loss = 1.3077, train acc = 0.6250
# Epoch 52, Iter 350,train loss = 1.1344, train acc = 0.6562
# Epoch 52, Iter 400,train loss = 1.2138, train acc = 0.6250
# Epoch 52, Iter 450,train loss = 1.2058, train acc = 0.6562
# Epoch 52, Iter 500,train loss = 1.2157, train acc = 0.6875
# Epoch 52, val loss = 1.5136, val acc = 0.3839
# 未达到期望，未保存模型
# 53
# Epoch 53, Iter 050,train loss = 1.2260, train acc = 0.5938
# Epoch 53, Iter 100,train loss = 1.3409, train acc = 0.5938
# Epoch 53, Iter 150,train loss = 1.1921, train acc = 0.6875
# Epoch 53, Iter 200,train loss = 1.2464, train acc = 0.5312
# Epoch 53, Iter 250,train loss = 1.2186, train acc = 0.4688
# Epoch 53, Iter 300,train loss = 1.1310, train acc = 0.6562
# Epoch 53, Iter 350,train loss = 1.1951, train acc = 0.6562
# Epoch 53, Iter 400,train loss = 1.2960, train acc = 0.5000
# Epoch 53, Iter 450,train loss = 1.1258, train acc = 0.6875
# Epoch 53, Iter 500,train loss = 1.1277, train acc = 0.5625
# Epoch 53, val loss = 1.5037, val acc = 0.4028
# 未达到期望，未保存模型
# 54
# Epoch 54, Iter 050,train loss = 1.1666, train acc = 0.6250
# Epoch 54, Iter 100,train loss = 1.3864, train acc = 0.4688
# Epoch 54, Iter 150,train loss = 1.1594, train acc = 0.7188
# Epoch 54, Iter 200,train loss = 1.1540, train acc = 0.7812
# Epoch 54, Iter 250,train loss = 1.2647, train acc = 0.6250
# Epoch 54, Iter 300,train loss = 1.2339, train acc = 0.7188
# Epoch 54, Iter 350,train loss = 1.1580, train acc = 0.6875
# Epoch 54, Iter 400,train loss = 1.2502, train acc = 0.6250
# Epoch 54, Iter 450,train loss = 1.3581, train acc = 0.4688
# Epoch 54, Iter 500,train loss = 1.1925, train acc = 0.7188
# Epoch 54, val loss = 1.5142, val acc = 0.3995
# 未达到期望，未保存模型
# 55
# Epoch 55, Iter 050,train loss = 1.2176, train acc = 0.6875
# Epoch 55, Iter 100,train loss = 1.1140, train acc = 0.7188
# Epoch 55, Iter 150,train loss = 1.2060, train acc = 0.6250
# Epoch 55, Iter 200,train loss = 1.1405, train acc = 0.7188
# Epoch 55, Iter 250,train loss = 1.3003, train acc = 0.5312
# Epoch 55, Iter 300,train loss = 1.1871, train acc = 0.6562
# Epoch 55, Iter 350,train loss = 1.2732, train acc = 0.5938
# Epoch 55, Iter 400,train loss = 1.2073, train acc = 0.5938
# Epoch 55, Iter 450,train loss = 1.1529, train acc = 0.7500
# Epoch 55, Iter 500,train loss = 1.2020, train acc = 0.6562
# Epoch 55, val loss = 1.4920, val acc = 0.4014
# 未达到期望，未保存模型
# 56
# Epoch 56, Iter 050,train loss = 1.2128, train acc = 0.5938
# Epoch 56, Iter 100,train loss = 1.2050, train acc = 0.6250
# Epoch 56, Iter 150,train loss = 1.2301, train acc = 0.5000
# Epoch 56, Iter 200,train loss = 1.2538, train acc = 0.7188
# Epoch 56, Iter 250,train loss = 1.1242, train acc = 0.6875
# Epoch 56, Iter 300,train loss = 1.1861, train acc = 0.6562
# Epoch 56, Iter 350,train loss = 1.1435, train acc = 0.6875
# Epoch 56, Iter 400,train loss = 1.1896, train acc = 0.6875
# Epoch 56, Iter 450,train loss = 1.2423, train acc = 0.6562
# Epoch 56, Iter 500,train loss = 1.1176, train acc = 0.6250
# Epoch 56, val loss = 1.5065, val acc = 0.3835
# 未达到期望，未保存模型
# 57
# Epoch 57, Iter 050,train loss = 1.3169, train acc = 0.6250
# Epoch 57, Iter 100,train loss = 1.2448, train acc = 0.5938
# Epoch 57, Iter 150,train loss = 1.1667, train acc = 0.5625
# Epoch 57, Iter 200,train loss = 1.3071, train acc = 0.5938
# Epoch 57, Iter 250,train loss = 1.2761, train acc = 0.5938
# Epoch 57, Iter 300,train loss = 1.2804, train acc = 0.5938
# Epoch 57, Iter 350,train loss = 1.2785, train acc = 0.6562
# Epoch 57, Iter 400,train loss = 1.1576, train acc = 0.6562
# Epoch 57, Iter 450,train loss = 1.2263, train acc = 0.6875
# Epoch 57, Iter 500,train loss = 1.2734, train acc = 0.5000
# Epoch 57, val loss = 1.5041, val acc = 0.3906
# 未达到期望，未保存模型
# 58
# Epoch 58, Iter 050,train loss = 1.2562, train acc = 0.5938
# Epoch 58, Iter 100,train loss = 1.2706, train acc = 0.5312
# Epoch 58, Iter 150,train loss = 1.2117, train acc = 0.7812
# Epoch 58, Iter 200,train loss = 1.3128, train acc = 0.5000
# Epoch 58, Iter 250,train loss = 1.1572, train acc = 0.8125
# Epoch 58, Iter 300,train loss = 1.1656, train acc = 0.7500
# Epoch 58, Iter 350,train loss = 1.2308, train acc = 0.6562
# Epoch 58, Iter 400,train loss = 1.2682, train acc = 0.5000
# Epoch 58, Iter 450,train loss = 1.2239, train acc = 0.6562
# Epoch 58, Iter 500,train loss = 1.1966, train acc = 0.5938
# Epoch 58, val loss = 1.5118, val acc = 0.3965
# 未达到期望，未保存模型
# 59
# Epoch 59, Iter 050,train loss = 1.2695, train acc = 0.5625
# Epoch 59, Iter 100,train loss = 1.2394, train acc = 0.6562
# Epoch 59, Iter 150,train loss = 1.2944, train acc = 0.5938
# Epoch 59, Iter 200,train loss = 1.2360, train acc = 0.5625
# Epoch 59, Iter 250,train loss = 1.1976, train acc = 0.6250
# Epoch 59, Iter 300,train loss = 1.3106, train acc = 0.6250
# Epoch 59, Iter 350,train loss = 1.2024, train acc = 0.6875
# Epoch 59, Iter 400,train loss = 1.2875, train acc = 0.5312
# Epoch 59, Iter 450,train loss = 1.3012, train acc = 0.5312
# Epoch 59, Iter 500,train loss = 1.2082, train acc = 0.5938
# Epoch 59, val loss = 1.5071, val acc = 0.4072
# 未达到期望，未保存模型
# 60
# Epoch 60, Iter 050,train loss = 1.2926, train acc = 0.4375
# Epoch 60, Iter 100,train loss = 1.1545, train acc = 0.6250
# Epoch 60, Iter 150,train loss = 1.0647, train acc = 0.8438
# Epoch 60, Iter 200,train loss = 1.3062, train acc = 0.5625
# Epoch 60, Iter 250,train loss = 1.3371, train acc = 0.2812
# Epoch 60, Iter 300,train loss = 1.1782, train acc = 0.6562
# Epoch 60, Iter 350,train loss = 1.2116, train acc = 0.6562
# Epoch 60, Iter 400,train loss = 1.2542, train acc = 0.5625
# Epoch 60, Iter 450,train loss = 1.1688, train acc = 0.7188
# Epoch 60, Iter 500,train loss = 1.1501, train acc = 0.7500
# Epoch 60, val loss = 1.5045, val acc = 0.3835
# 未达到期望，未保存模型
# 61
# Epoch 61, Iter 050,train loss = 1.1677, train acc = 0.8125
# Epoch 61, Iter 100,train loss = 1.2046, train acc = 0.7188
# Epoch 61, Iter 150,train loss = 1.1574, train acc = 0.8438
# Epoch 61, Iter 200,train loss = 1.3327, train acc = 0.5312
# Epoch 61, Iter 250,train loss = 1.1422, train acc = 0.7188
# Epoch 61, Iter 300,train loss = 1.1263, train acc = 0.8125
# Epoch 61, Iter 350,train loss = 1.1529, train acc = 0.5938
# Epoch 61, Iter 400,train loss = 1.1849, train acc = 0.6875
# Epoch 61, Iter 450,train loss = 1.3260, train acc = 0.5312
# Epoch 61, Iter 500,train loss = 1.2432, train acc = 0.6562
# Epoch 61, val loss = 1.5095, val acc = 0.3864
# 未达到期望，未保存模型
# 62
# Epoch 62, Iter 050,train loss = 1.1738, train acc = 0.6562
# Epoch 62, Iter 100,train loss = 1.1995, train acc = 0.6562
# Epoch 62, Iter 150,train loss = 1.1911, train acc = 0.6875
# Epoch 62, Iter 200,train loss = 1.1511, train acc = 0.7188
# Epoch 62, Iter 250,train loss = 1.2181, train acc = 0.6562
# Epoch 62, Iter 300,train loss = 1.2013, train acc = 0.6250
# Epoch 62, Iter 350,train loss = 1.4602, train acc = 0.4062
# Epoch 62, Iter 400,train loss = 1.2335, train acc = 0.6250
# Epoch 62, Iter 450,train loss = 1.2638, train acc = 0.5625
# Epoch 62, Iter 500,train loss = 1.1440, train acc = 0.7812
# Epoch 62, val loss = 1.5087, val acc = 0.3867
# 未达到期望，未保存模型
# 63
# Epoch 63, Iter 050,train loss = 1.2524, train acc = 0.6875
# Epoch 63, Iter 100,train loss = 1.1696, train acc = 0.6875
# Epoch 63, Iter 150,train loss = 1.2425, train acc = 0.6250
# Epoch 63, Iter 200,train loss = 1.1766, train acc = 0.7188
# Epoch 63, Iter 250,train loss = 1.3074, train acc = 0.6250
# Epoch 63, Iter 300,train loss = 1.2451, train acc = 0.5000
# Epoch 63, Iter 350,train loss = 1.2778, train acc = 0.6250
# Epoch 63, Iter 400,train loss = 1.2743, train acc = 0.4688
# Epoch 63, Iter 450,train loss = 1.1460, train acc = 0.7188
# Epoch 63, Iter 500,train loss = 1.1839, train acc = 0.6875
# Epoch 63, val loss = 1.5004, val acc = 0.3948
# 未达到期望，未保存模型
# 64
# Epoch 64, Iter 050,train loss = 1.2081, train acc = 0.6875
# Epoch 64, Iter 100,train loss = 1.1374, train acc = 0.7188
# Epoch 64, Iter 150,train loss = 1.4944, train acc = 0.2812
# Epoch 64, Iter 200,train loss = 1.1492, train acc = 0.6875
# Epoch 64, Iter 250,train loss = 1.2018, train acc = 0.5625
# Epoch 64, Iter 300,train loss = 1.2864, train acc = 0.6250
# Epoch 64, Iter 350,train loss = 1.2394, train acc = 0.6250
# Epoch 64, Iter 400,train loss = 1.2802, train acc = 0.5625
# Epoch 64, Iter 450,train loss = 1.1319, train acc = 0.6875
# Epoch 64, Iter 500,train loss = 1.1716, train acc = 0.5625
# Epoch 64, val loss = 1.5131, val acc = 0.3741
# 未达到期望，未保存模型
# 65
# Epoch 65, Iter 050,train loss = 1.1202, train acc = 0.7500
# Epoch 65, Iter 100,train loss = 1.1582, train acc = 0.5938
# Epoch 65, Iter 150,train loss = 1.2418, train acc = 0.5000
# Epoch 65, Iter 200,train loss = 1.2732, train acc = 0.4688
# Epoch 65, Iter 250,train loss = 1.2268, train acc = 0.5625
# Epoch 65, Iter 300,train loss = 1.1448, train acc = 0.7500
# Epoch 65, Iter 350,train loss = 1.2185, train acc = 0.6875
# Epoch 65, Iter 400,train loss = 1.1766, train acc = 0.6875
# Epoch 65, Iter 450,train loss = 1.1198, train acc = 0.7500
# Epoch 65, Iter 500,train loss = 1.1283, train acc = 0.5625
# Epoch 65, val loss = 1.5149, val acc = 0.3881
# 未达到期望，未保存模型
# 66
# Epoch 66, Iter 050,train loss = 1.2615, train acc = 0.5938
# Epoch 66, Iter 100,train loss = 1.2271, train acc = 0.5938
# Epoch 66, Iter 150,train loss = 1.3240, train acc = 0.4688
# Epoch 66, Iter 200,train loss = 1.1927, train acc = 0.6562
# Epoch 66, Iter 250,train loss = 1.2416, train acc = 0.5938
# Epoch 66, Iter 300,train loss = 1.1236, train acc = 0.7500
# Epoch 66, Iter 350,train loss = 1.2557, train acc = 0.6562
# Epoch 66, Iter 400,train loss = 1.1946, train acc = 0.5938
# Epoch 66, Iter 450,train loss = 1.1198, train acc = 0.8438
# Epoch 66, Iter 500,train loss = 1.1484, train acc = 0.5938
# Epoch 66, val loss = 1.5026, val acc = 0.3955
# 未达到期望，未保存模型
# 67
# Epoch 67, Iter 050,train loss = 1.1732, train acc = 0.7500
# Epoch 67, Iter 100,train loss = 1.1648, train acc = 0.5938
# Epoch 67, Iter 150,train loss = 1.2793, train acc = 0.5312
# Epoch 67, Iter 200,train loss = 1.2456, train acc = 0.5625
# Epoch 67, Iter 250,train loss = 1.2229, train acc = 0.7188
# Epoch 67, Iter 300,train loss = 1.1948, train acc = 0.6250
# Epoch 67, Iter 350,train loss = 1.1288, train acc = 0.6562
# Epoch 67, Iter 400,train loss = 1.2245, train acc = 0.6562
# Epoch 67, Iter 450,train loss = 1.1875, train acc = 0.6875
# Epoch 67, Iter 500,train loss = 1.0983, train acc = 0.7812
# Epoch 67, val loss = 1.5074, val acc = 0.3927
# 未达到期望，未保存模型
# 68
# Epoch 68, Iter 050,train loss = 1.1880, train acc = 0.6875
# Epoch 68, Iter 100,train loss = 1.1877, train acc = 0.7188
# Epoch 68, Iter 150,train loss = 1.2011, train acc = 0.6562
# Epoch 68, Iter 200,train loss = 1.2251, train acc = 0.6562
# Epoch 68, Iter 250,train loss = 1.2327, train acc = 0.5938
# Epoch 68, Iter 300,train loss = 1.2695, train acc = 0.6250
# Epoch 68, Iter 350,train loss = 1.1490, train acc = 0.5938
# Epoch 68, Iter 400,train loss = 1.1664, train acc = 0.7500
# Epoch 68, Iter 450,train loss = 1.2662, train acc = 0.6875
# Epoch 68, Iter 500,train loss = 1.2352, train acc = 0.5938
# Epoch 68, val loss = 1.5027, val acc = 0.3849
# 未达到期望，未保存模型
# 69
# Epoch 69, Iter 050,train loss = 1.2182, train acc = 0.6562
# Epoch 69, Iter 100,train loss = 1.2006, train acc = 0.6250
# Epoch 69, Iter 150,train loss = 1.2521, train acc = 0.5312
# Epoch 69, Iter 200,train loss = 1.1040, train acc = 0.8125
# Epoch 69, Iter 250,train loss = 1.1599, train acc = 0.6250
# Epoch 69, Iter 300,train loss = 1.3257, train acc = 0.4062
# Epoch 69, Iter 350,train loss = 1.2851, train acc = 0.4375
# Epoch 69, Iter 400,train loss = 1.2461, train acc = 0.6562
# Epoch 69, Iter 450,train loss = 1.2577, train acc = 0.5938
# Epoch 69, Iter 500,train loss = 1.2454, train acc = 0.5938
# Epoch 69, val loss = 1.5151, val acc = 0.3813
# 未达到期望，未保存模型
# 70
# Epoch 70, Iter 050,train loss = 1.3437, train acc = 0.5312
# Epoch 70, Iter 100,train loss = 1.1655, train acc = 0.7188
# Epoch 70, Iter 150,train loss = 1.2302, train acc = 0.6562
# Epoch 70, Iter 200,train loss = 1.1910, train acc = 0.6250
# Epoch 70, Iter 250,train loss = 1.2077, train acc = 0.7188
# Epoch 70, Iter 300,train loss = 1.1665, train acc = 0.7500
# Epoch 70, Iter 350,train loss = 1.1739, train acc = 0.7500
# Epoch 70, Iter 400,train loss = 1.2584, train acc = 0.6562
# Epoch 70, Iter 450,train loss = 1.2274, train acc = 0.7188
# Epoch 70, Iter 500,train loss = 1.1401, train acc = 0.7500
# Epoch 70, val loss = 1.4958, val acc = 0.4013
# 未达到期望，未保存模型
# 71
# Epoch 71, Iter 050,train loss = 1.1082, train acc = 0.6562
# Epoch 71, Iter 100,train loss = 1.1916, train acc = 0.6875
# Epoch 71, Iter 150,train loss = 1.1500, train acc = 0.7500
# Epoch 71, Iter 200,train loss = 1.1751, train acc = 0.7812
# Epoch 71, Iter 250,train loss = 1.1507, train acc = 0.6250
# Epoch 71, Iter 300,train loss = 1.2427, train acc = 0.6562
# Epoch 71, Iter 350,train loss = 1.1635, train acc = 0.6250
# Epoch 71, Iter 400,train loss = 1.1894, train acc = 0.6250
# Epoch 71, Iter 450,train loss = 1.2052, train acc = 0.6250
# Epoch 71, Iter 500,train loss = 1.2004, train acc = 0.7188
# Epoch 71, val loss = 1.4906, val acc = 0.4126
# 未达到期望，未保存模型
# 72
# Epoch 72, Iter 050,train loss = 1.1697, train acc = 0.7500
# Epoch 72, Iter 100,train loss = 1.1966, train acc = 0.6875
# Epoch 72, Iter 150,train loss = 1.2427, train acc = 0.5625
# Epoch 72, Iter 200,train loss = 1.1993, train acc = 0.7188
# Epoch 72, Iter 250,train loss = 1.0892, train acc = 0.6875
# Epoch 72, Iter 300,train loss = 1.2058, train acc = 0.6250
# Epoch 72, Iter 350,train loss = 1.2442, train acc = 0.5312
# Epoch 72, Iter 400,train loss = 1.2627, train acc = 0.5938
# Epoch 72, Iter 450,train loss = 1.1576, train acc = 0.6562
# Epoch 72, Iter 500,train loss = 1.2650, train acc = 0.5625
# Epoch 72, val loss = 1.4986, val acc = 0.4009
# 未达到期望，未保存模型
# 73
# Epoch 73, Iter 050,train loss = 1.2003, train acc = 0.5312
# Epoch 73, Iter 100,train loss = 1.1970, train acc = 0.6562
# Epoch 73, Iter 150,train loss = 1.1505, train acc = 0.7188
# Epoch 73, Iter 200,train loss = 1.2048, train acc = 0.6562
# Epoch 73, Iter 250,train loss = 1.1767, train acc = 0.7500
# Epoch 73, Iter 300,train loss = 1.2141, train acc = 0.5938
# Epoch 73, Iter 350,train loss = 1.2898, train acc = 0.5312
# Epoch 73, Iter 400,train loss = 1.1731, train acc = 0.6250
# Epoch 73, Iter 450,train loss = 1.2235, train acc = 0.5312
# Epoch 73, Iter 500,train loss = 1.2060, train acc = 0.6562
# Epoch 73, val loss = 1.4981, val acc = 0.3964
# 未达到期望，未保存模型
# 74
# Epoch 74, Iter 050,train loss = 1.2270, train acc = 0.6875
# Epoch 74, Iter 100,train loss = 1.2153, train acc = 0.6562
# Epoch 74, Iter 150,train loss = 1.2446, train acc = 0.7188
# Epoch 74, Iter 200,train loss = 1.1265, train acc = 0.7188
# Epoch 74, Iter 250,train loss = 1.1888, train acc = 0.6562
# Epoch 74, Iter 300,train loss = 1.0411, train acc = 0.7500
# Epoch 74, Iter 350,train loss = 1.1300, train acc = 0.8438
# Epoch 74, Iter 400,train loss = 1.1649, train acc = 0.6562
# Epoch 74, Iter 450,train loss = 1.2277, train acc = 0.6562
# Epoch 74, Iter 500,train loss = 1.2444, train acc = 0.5625
# Epoch 74, val loss = 1.5192, val acc = 0.4032
# 未达到期望，未保存模型
# 75
# Epoch 75, Iter 050,train loss = 1.1934, train acc = 0.5938
# Epoch 75, Iter 100,train loss = 1.2266, train acc = 0.6875
# Epoch 75, Iter 150,train loss = 1.2154, train acc = 0.6562
# Epoch 75, Iter 200,train loss = 1.0972, train acc = 0.8125
# Epoch 75, Iter 250,train loss = 1.1599, train acc = 0.6875
# Epoch 75, Iter 300,train loss = 1.2202, train acc = 0.6562
# Epoch 75, Iter 350,train loss = 1.2045, train acc = 0.6875
# Epoch 75, Iter 400,train loss = 1.2365, train acc = 0.6562
# Epoch 75, Iter 450,train loss = 1.2632, train acc = 0.6250
# Epoch 75, Iter 500,train loss = 1.2619, train acc = 0.6250
# Epoch 75, val loss = 1.5066, val acc = 0.3742
# 未达到期望，未保存模型
# 76
# Epoch 76, Iter 050,train loss = 1.3035, train acc = 0.5938
# Epoch 76, Iter 100,train loss = 1.1854, train acc = 0.6875
# Epoch 76, Iter 150,train loss = 1.2460, train acc = 0.5000
# Epoch 76, Iter 200,train loss = 1.1499, train acc = 0.8125
# Epoch 76, Iter 250,train loss = 1.2293, train acc = 0.7188
# Epoch 76, Iter 300,train loss = 1.1713, train acc = 0.6875
# Epoch 76, Iter 350,train loss = 1.1165, train acc = 0.7500
# Epoch 76, Iter 400,train loss = 1.2036, train acc = 0.6562
# Epoch 76, Iter 450,train loss = 1.2029, train acc = 0.6250
# Epoch 76, Iter 500,train loss = 1.2219, train acc = 0.6562
# Epoch 76, val loss = 1.5036, val acc = 0.4036
# 未达到期望，未保存模型
# 77
# Epoch 77, Iter 050,train loss = 1.1957, train acc = 0.6875
# Epoch 77, Iter 100,train loss = 1.0968, train acc = 0.8125
# Epoch 77, Iter 150,train loss = 1.1845, train acc = 0.7188
# Epoch 77, Iter 200,train loss = 1.1620, train acc = 0.6250
# Epoch 77, Iter 250,train loss = 1.2032, train acc = 0.6250
# Epoch 77, Iter 300,train loss = 1.2287, train acc = 0.6875
# Epoch 77, Iter 350,train loss = 1.2497, train acc = 0.6562
# Epoch 77, Iter 400,train loss = 1.1381, train acc = 0.6250
# Epoch 77, Iter 450,train loss = 1.2605, train acc = 0.6250
# Epoch 77, Iter 500,train loss = 1.2011, train acc = 0.6875
# Epoch 77, val loss = 1.4921, val acc = 0.4019
# 未达到期望，未保存模型
# 78
# Epoch 78, Iter 050,train loss = 1.1349, train acc = 0.7500
# Epoch 78, Iter 100,train loss = 1.2305, train acc = 0.6875
# Epoch 78, Iter 150,train loss = 1.3020, train acc = 0.5000
# Epoch 78, Iter 200,train loss = 1.1822, train acc = 0.7500
# Epoch 78, Iter 250,train loss = 1.2661, train acc = 0.5000
# Epoch 78, Iter 300,train loss = 1.1086, train acc = 0.8125
# Epoch 78, Iter 350,train loss = 1.2114, train acc = 0.7500
# Epoch 78, Iter 400,train loss = 1.2035, train acc = 0.5625
# Epoch 78, Iter 450,train loss = 1.1940, train acc = 0.5938
# Epoch 78, Iter 500,train loss = 1.1684, train acc = 0.7188
# Epoch 78, val loss = 1.5046, val acc = 0.3971
# 未达到期望，未保存模型
# 79
# Epoch 79, Iter 050,train loss = 1.2712, train acc = 0.5938
# Epoch 79, Iter 100,train loss = 1.1719, train acc = 0.6562
# Epoch 79, Iter 150,train loss = 1.1297, train acc = 0.6875
# Epoch 79, Iter 200,train loss = 1.3346, train acc = 0.4688
# Epoch 79, Iter 250,train loss = 1.2005, train acc = 0.7188
# Epoch 79, Iter 300,train loss = 1.2126, train acc = 0.5938
# Epoch 79, Iter 350,train loss = 1.1118, train acc = 0.7812
# Epoch 79, Iter 400,train loss = 1.1988, train acc = 0.7188
# Epoch 79, Iter 450,train loss = 1.1870, train acc = 0.6562
# Epoch 79, Iter 500,train loss = 1.1746, train acc = 0.7188
# Epoch 79, val loss = 1.5102, val acc = 0.3955
# 未达到期望，未保存模型
# 80
# Epoch 80, Iter 050,train loss = 1.2222, train acc = 0.5938
# Epoch 80, Iter 100,train loss = 1.2693, train acc = 0.5000
# Epoch 80, Iter 150,train loss = 1.1176, train acc = 0.8125
# Epoch 80, Iter 200,train loss = 1.1520, train acc = 0.7188
# Epoch 80, Iter 250,train loss = 1.1029, train acc = 0.6875
# Epoch 80, Iter 300,train loss = 1.2551, train acc = 0.5625
# Epoch 80, Iter 350,train loss = 1.1805, train acc = 0.7188
# Epoch 80, Iter 400,train loss = 1.2506, train acc = 0.5938
# Epoch 80, Iter 450,train loss = 1.1235, train acc = 0.7812
# Epoch 80, Iter 500,train loss = 1.1839, train acc = 0.6562
# Epoch 80, val loss = 1.4907, val acc = 0.3857
# 未达到期望，未保存模型
# best acc: 0.0000
